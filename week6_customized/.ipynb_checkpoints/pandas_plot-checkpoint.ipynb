# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dateutil import parser
from matplotlib import rcParams, style

style.use('ggplot')
# rcParams['font.family'] = 'NanumGothicOTF'
rcParams['font.size'] = 12

k = pd.read_csv('k_league_fw_goals.csv', index_col=0)
l = pd.read_csv('liverpool_14_15.csv', index_col=0, date_parser=parser.parse)
c = pd.read_csv('seac_coffee.csv')

# %%
# line graph
l.plot()

# %%
l['CumWin'].plot()

# %%
l[['CumWin', 'CumLost']].plot()

# %%
c.plot()
# shows numeric data only!

# %%
c[['A', 'C', 'E', 'S']].sum().plot(kind='bar')

# %%
c[['A', 'C', 'E', 'S']].sum().plot(kind='barh')

# %%
c.iloc[:5].plot(kind='bar')

# %%
c.columns
# Out:
# Index(['Unnamed: 0', 'A', 'C', 'E', 'S'], dtype='object')

# %%
c2 = c.set_index('Unnamed: 0')
c2.index.name = None
c2.head()
# Out:
#             A   C   E   S
# 서울특별시 강남구  26  40  53  61
# 경기도 수원시    30  27  39  18
# 서울특별시 서초구  10  23  27  37
# 경기도 성남시     8  23  48  33
# 경기도 용인시    14  22  21  17

# %%
c2.iloc[:5].plot(kind='bar')

# %%
c2.iloc[:5].plot(kind='barh')

# %%
c2.iloc[:5].plot(kind='bar', stacked=True)

# %%
c2.iloc[:5].plot(kind='bar', stacked=True, alpha=0.5)

# %%
c2.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x109d42f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10a6f5780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10a741f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10a77ce80>]], dtype=object)
# /Users/dennisbaek/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/matplotlib/font_manager.py:1282: UserWarning: findfont: Font family ['NanumGothicOTF'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
c2.plot(kind='kde')

# %%
c2['S'].hist(normed=True)
c2['S'].plot(kind='kde', style='k--')

# %%
r = pd.Series(np.random.normal(0, 1, size=100))
r.hist(normed=True)
r.plot(kind='kde', style='k')

# %%
r2 = pd.Series(np.random.normal(10, 2, size=100))
new = r.append(r2)
new.hist(normed=True)
new.plot(kind='kde', style='k')

# %%
new.hist(normed=True, alpha=0.2, color='k')
new.plot(kind='kde', style='k--')

# %%
plt.scatter(k['play'], k['goal'], marker='^')
# Out:
# /Users/dennisbaek/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
plt.title('play / goal')
plt.scatter(k['play'], k['goal'], color='r')
# Out:
# /Users/dennisbaek/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
pd.scatter_matrix(c, diagonal='kde', color='k')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10c090518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c5f7ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c64c2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c685208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10c9003c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c934f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c9887b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c953d68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10cb0c860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cb55a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cb95a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cbe24e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10cd1ada0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cd61f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cda2cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cdf0630>]], dtype=object)
# /Users/dennisbaek/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/matplotlib/font_manager.py:1282: UserWarning: findfont: Font family ['NanumGothicOTF'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /Users/dennisbaek/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
with plt.xkcd():
    new.hist(normed=True, alpha=0.2, color='k')
    new.plot(kind='kde', style='k--')
