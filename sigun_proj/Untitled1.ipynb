# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("seoul_csv_gu_list.xlsx")

# %%
df.head()
# Out:
#    CU  강남구  177
# 0  CU  강동구   64
# 1  CU  강북구   50
# 2  CU  강서구   84
# 3  CU  관악구   94
# 4  CU  광진구   74

# %%
df
# Out:
#               CU   강남구  177
# 0             CU   강동구   64
# 1             CU   강북구   50
# 2             CU   강서구   84
# 3             CU   관악구   94
# 4             CU   광진구   74
# 5             CU   구로구   58
# 6             CU   금천구   45
# 7             CU   노원구   71
# 8             CU   도봉구   39
# 9             CU  동대문구   83
# 10            CU   동작구   62
# 11            CU   마포구   93
# 12            CU  서대문구   77
# 13            CU   서초구   94
# 14            CU   성동구   53
# 15            CU   성북구   59
# 16            CU   송파구   95
# 17            CU   양천구   56
# 18            CU  영등포구   70
# 19            CU   용산구   60
# 20            CU   은평구   64
# 21            CU   종로구   79
# 22            CU    중구   72
# 23            CU   중랑구   45
# 24          gs25   강남구  225
# 25          gs26   강동구   87
# 26          gs27   강북구   52
# 27          gs28   강서구   87
# 28          gs29   관악구  114
# 29          gs30   광진구   74
# ..           ...   ...  ...
# 69  seven eleven   용산구   41
# ...

# %%
df.merge('right')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-f5e287ef5279> in <module>()
# ----> 1 df.merge('right')
#
# /Users/dennisbaek/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#    4328                      left_on=left_on, right_on=right_on,
#    4329                      left_index=left_index, right_index=right_index, sort=sort,
# -> 4330                      suffixes=suffixes, copy=copy, indicator=indicator)
#    4331
#    4332     def round(self, decimals=0, out=None):
#
# /Users/dennisbaek/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/pandas/tools/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
# ...
